# %%
import pandas as pd

# %% [markdown]
# ### Load Data into Pandas Library

# %%
df = pd.read_csv("pokemon_data.csv")
print (df)

#load in excel files too or txt 

#df = pd.read_excel ("pokemon_data.xlsx")
#df = pd.read_csv("pokemon_data.txt", delimiter = "/t")

# can print top 5 or bottom 
# print(df.head (5))
# print (df.tail(5))
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### Read Data in Pandas

# %%
#### Read Headers
print (df.columns)

## Read each Column
#print(df[['Name', 'Type 1', 'HP']])

## Read Each Row
#print(df.iloc[0:4]) # iloc -> integer location

#iterate through each row 
# for index, row in df.iterrows():
#     print(index, row['Name'])

# used for finding specific data that isn't just integer based but more informational. Access multiple rows that have grass in type 1
#df.loc[df['Type 1'] == "Grass"]

## Read a specific location (R,C)
#print(df.iloc[2,1])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### Sorting/Describing Data

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1,0]) # ascending to descending 

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ## Making Changes to the Data

# %%
# add all the stats together and get a "total" category 

#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# remove total column/ drop a column
# df = df.drop(columns=['Total']) 


df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# make columns as a list 
cols = list(df.columns)
#moving "total" to be next to type 1
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Saving our Data (Exporting into Desired Format)

# %%
# save to csv 

df.to_csv("modified.csv")

# save to excel 

#df.to_excel("modified.xlsx")

#save to txt 
#df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
#filtering using & sign 
# or sign is |

new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# not allow Mega in the name 

#df.loc[~df["Name"].str.contains ("Mega")]

# is Type 1 grass or fire 
#import regular expressions (import re)
# df.loc[df["Type1"].str.contains ("Fire|Grass", regex = True)]

# if you want the names starting with pi
# df.loc[df["Name"].str.contains ("^pi[a,z]*", flags = re.I, regex = True)]

# resetting index and getting rid of old indces 
new_df.reset_index(drop=True, inplace=True)

new_df

new_df.to_csv('filtered.csv')

# %% [markdown]
# ### Conditional Changes

# %%
# Change dataframe, if you want to change Fire to Flamer in Type 1 
#df.loc[df["Type1"] == "Fire", "Type1"] = "Flamer"

# if this specific condition is met, then make generation and legendary test1 and test 2
# df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# df

df = pd.read_csv('modified.csv')

df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0             0    1              Bulbasaur    Grass  Poison    318  45
# 1             1    2                Ivysaur    Grass  Poison    405  60
# 2             2    3               Venusaur    Grass  Poison    525  80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4             4    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         795  719                Diancie     Rock   Fairy    600  50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         799  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Aggregate Statistics (Groupby)

# %%
df = pd.read_csv ("modified.csv")

# %%
# the average HP and attack of all the pokemon grouped by which type they are aka do specific pokemons have higher skills for somehting 
# who has the highest defense 
df.groupby(["Type 1"]). mean().sort_values("Defense", ascending = False)

# summ

# df.groupby(["Type 1"]). sum()

#count -> how many pokemons are bug or dark etc.. 
#df.groupby(["Type 1"]). count()
# OR
#df.groupby(["Type 1"]). count()["count"]
# OR 
# df.groupby(["Type 1", "Type 2"]). count()["count"]
# Out:
#           Unnamed: 0           #       Total         HP      Attack  \
# Type 1
# Steel     486.296296  442.851852  487.703704  65.222222   92.703704
# Rock      431.840909  392.727273  453.750000  65.363636   92.863636
# Dragon    521.843750  474.375000  550.531250  83.312500  112.125000
# Ground    392.312500  356.281250  437.500000  73.781250   95.750000
# Ghost     536.281250  486.500000  439.562500  64.437500   73.781250
# Water     333.312500  303.089286  430.455357  72.062500   74.151786
# Ice       465.666667  423.541667  433.458333  72.000000   72.750000
# Grass     380.414286  344.871429  421.142857  67.271429   73.214286
# Bug       368.072464  334.492754  378.927536  56.884058   70.971014
# Dark      507.387097  461.354839  445.741935  66.806452   88.387097
# Poison    278.285714  251.785714  399.142857  67.250000   74.678571
# Fire      360.942308  327.403846  458.076923  69.903846   84.769231
# Psychic   420.105263  380.807018  475.947368  70.631579   71.456140
# ...

# %% [markdown]
# ## Working with Large Datasets

# %%
# Make dataset smaller by using groupby function

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])

# %% [markdown]
# ## Series

# %%
# handles one dimensional arrays

# %%
A = pd.Series([2,3,4,5], index=["a","b","c","d"])

# %%
A.values
# Out:
# array([2, 3, 4, 5])

# %%
A["a":"c"]
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
grads_dict = {'A':4,'B':3.5,'C':3,'D':2.5}
grads = pd.Series(grads_dict)

# %%
grads.values
# Out:
# array([4. , 3.5, 3. , 2.5])

# %%
marks_dict = {'A':85,'B':75,'C':65,'D':55}
marks = pd.Series(marks_dict)

# %%
marks
# Out:
# A    85
# B    75
# C    65
# D    55
# dtype: int64

# %%
marks["A"]
# Out:
# 85

# %%
D = pd.DataFrame({'Marks':marks,'Grades':grads})

# %%
D
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
D.T
# Out:
#            A     B     C     D
# Marks   85.0  75.0  65.0  55.0
# Grades   4.0   3.5   3.0   2.5

# %%
D.values[2,0]
# Out:
# 65.0

# %%
D.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
D['ScaledMarks'] = 100*(D['Marks']/90)

# %%
D
# Out:
#    Marks  Grades  ScaledMarks
# A     85     4.0    94.444444
# B     75     3.5    83.333333
# C     65     3.0    72.222222
# D     55     2.5    61.111111

# %%
del D['ScaledMarks']

# %%
G = D[D['Marks']>70]

# %%
G
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5

# %%
A = pd.DataFrame([{'a':1,'b':4},{'b':-3,'c':9}])

# %%
A
# Out:
#      a  b    c
# 0  1.0  4  NaN
# 1  NaN -3  9.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  4  0.0
# 1  0.0 -3  9.0

# %%
A.dropna?

# %%
A = pd.Series(['a','b','c'],index=[1,3,5])

# %%
A
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
A.loc[1:3] #explicit index
# Out:
# 1    a
# 3    b
# dtype: object

# %%
A.iloc[1:3] #implicit index
# Out:
# 3    b
# 5    c
# dtype: object

# %%
D.iloc[2,:]
# Out:
# Marks     65.0
# Grades     3.0
# Name: C, dtype: float64

# %%
D.iloc[::-1,:] #reverse all rows
# Out:
#    Marks  Grades
# D     55     2.5
# C     65     3.0
# B     75     3.5
# A     85     4.0

# %%
from sklearn.impute import SimpleImputer

# %%
#https://github.com/datapublishings/Course-python-data-science/blob/master/MasteringPythonZeroToHero_part2.ipynb
